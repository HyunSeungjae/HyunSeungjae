# %% [markdown]
# <a href="https://colab.research.google.com/github/HyunSeungjae/HyunSeungjae/blob/main/%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D_%EB%B0%9C%ED%91%9C%EC%9A%A9(%EC%99%B8%EB%B6%80%EB%AA%A8%EB%93%88).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>

<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
print(soup.select("a"))
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
print(soup.select("a")[0].string)
# Out:
# Elsie

# %%
#모듈 불러오기
from urllib import request
#기상청 서울날씨 불러오기
target = request.urlopen("http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109")

#BeautifulSoup으로 웹 페이지 분석
soup_kma = BeautifulSoup(target,"html.parser") 

print(soup_kma.select("data"))
# Out:
# [<data>
# <mode>A02</mode>
# <tmef>2021-05-19 00:00</tmef>
# <wf>맑음</wf>
# <tmn>15</tmn>
# <tmx>26</tmx>
# <reliability></reliability>
# <rnst>0</rnst>
# </data>, <data>
# <mode>A02</mode>
# <tmef>2021-05-19 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>15</tmn>
# <tmx>26</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>, <data>
# <mode>A02</mode>
# <tmef>2021-05-20 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>17</tmn>
# <tmx>26</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>, <data>
# <mode>A02</mode>
# <tmef>2021-05-20 12:00</tmef>
# <wf>흐림</wf>
# <tmn>17</tmn>
# <tmx>26</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>, <data>
# <mode>A02</mode>
# <tmef>2021-05-21 00:00</tmef>
# <wf>흐림</wf>
# <tmn>15</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>, <data>
# <mode>A02</mode>
# <tmef>2021-05-21 12:00</tmef>
# <wf>맑음</wf>
# <tmn>15</tmn>
# <tmx>25</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>, <data>
# ...

# %%
for data in soup_kma.select("data"):
  print("시간:", data.select_one("tmef").string)
  print("날씨:", data.select_one("wf").string)
  print("-"*20)
# Out:
# 시간: 2021-05-19 00:00
# 날씨: 맑음
# --------------------
# 시간: 2021-05-19 12:00
# 날씨: 구름많음
# --------------------
# 시간: 2021-05-20 00:00
# 날씨: 구름많음
# --------------------
# 시간: 2021-05-20 12:00
# 날씨: 흐림
# --------------------
# 시간: 2021-05-21 00:00
# 날씨: 흐림
# --------------------
# 시간: 2021-05-21 12:00
# 날씨: 맑음
# --------------------
# 시간: 2021-05-22 00:00
# 날씨: 맑음
# --------------------
# 시간: 2021-05-22 12:00
# 날씨: 맑음
# --------------------
# 시간: 2021-05-23 00:00
# 날씨: 맑음
# --------------------
# 시간: 2021-05-23 12:00
# 날씨: 맑음
# --------------------
# 시간: 2021-05-24 00:00
# 날씨: 구름많음
# --------------------
# 시간: 2021-05-25 00:00
# 날씨: 맑음
# --------------------
# 시간: 2021-05-26 00:00
# 날씨: 맑음
# --------------------
# 시간: 2021-05-19 00:00
# 날씨: 맑음
# --------------------
# 시간: 2021-05-19 12:00
# 날씨: 구름많음
# --------------------
# 시간: 2021-05-20 00:00
# 날씨: 구름많음
# --------------------
# 시간: 2021-05-20 12:00
# 날씨: 흐림
# --------------------
# 시간: 2021-05-21 00:00
# 날씨: 흐림
# --------------------
# ...

# %%
for location in soup_kma.select("location"):
  print("도시:", location.select_one("city").string)
  print("날씨:", location.select_one("wf").string)
  print("최저기온:", location.select_one("tmn").string)
  print("최고기온:", location.select_one("tmx").string)
  print()
# Out:
# 도시: 서울
# 날씨: 맑음
# 최저기온: 15
# 최고기온: 26
#
# 도시: 인천
# 날씨: 맑음
# 최저기온: 14
# 최고기온: 23
#
# 도시: 수원
# 날씨: 맑음
# 최저기온: 12
# 최고기온: 26
#
# 도시: 파주
# 날씨: 맑음
# 최저기온: 10
# 최고기온: 26
#
# 도시: 이천
# 날씨: 맑음
# 최저기온: 11
# 최고기온: 27
#
# 도시: 평택
# 날씨: 맑음
# 최저기온: 12
# 최고기온: 27
#
# 도시: 백령도
# 날씨: 맑음
# 최저기온: 13
# 최고기온: 23
#
# 도시: 과천
# 날씨: 맑음
# 최저기온: 11
# 최고기온: 27
#
# 도시: 광명
# 날씨: 맑음
# 최저기온: 14
# 최고기온: 25
#
# 도시: 강화
# 날씨: 맑음
# 최저기온: 12
# 최고기온: 23
#
# 도시: 김포
# 날씨: 맑음
# 최저기온: 13
# 최고기온: 25
#
# 도시: 시흥
# 날씨: 맑음
# 최저기온: 11
# 최고기온: 25
#
# 도시: 안산
# 날씨: 맑음
# 최저기온: 12
# 최고기온: 25
#
# 도시: 부천
# 날씨: 맑음
# 최저기온: 14
# 최고기온: 25
#
# 도시: 의정부
# 날씨: 맑음
# 최저기온: 12
# 최고기온: 27
#
# 도시: 고양
# 날씨: 맑음
# 최저기온: 11
# 최고기온: 27
#
# 도시: 양주
# 날씨: 맑음
# 최저기온: 10
# 최고기온: 26
#
# 도시: 동두천
# 날씨: 맑음
# 최저기온: 11
# 최고기온: 27
#
# 도시: 연천
# 날씨: 맑음
# 최저기온: 9
# 최고기온: 26
#
# 도시: 포천
# 날씨: 맑음
# 최저기온: 11
# 최고기온: 27
#
# 도시: 가평
# 날씨: 맑음
# 최저기온: 9
# 최고기온: 29
#
# 도시: 구리
# 날씨: 맑음
# 최저기온: 13
# 최고기온: 28
#
# 도시: 남양주
# 날씨: 맑음
# 최저기온: 10
# 최고기온: 28
#
# 도시: 양평
# 날씨: 맑음
# 최저기온: 12
# ...
